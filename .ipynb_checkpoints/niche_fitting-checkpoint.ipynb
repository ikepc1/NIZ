# %%
from fit import *
# %matplotlib widget
from utils import plot_event, plot_generator, get_data_files, preceding_noise_file

# %% [markdown]
# First set up the MC configuration, i.e. the data part for which we're simulating data.

# %%
data_date_and_time = '20190504034237'
data_files = get_data_files(data_date_and_time)
noise_files = [preceding_noise_file(f) for f in data_files]
cfg = CounterConfig(data_files, noise_files)

# %% [markdown]
# Now let's simulate an event with given shower parameters.

# %%
pars = [500.,2.e6,np.deg2rad(40.),np.deg2rad(315.), 450., -660.,-25.7,0,70]
ev = BasicParams.get_event(pars)
pe = ProcessEvents(cfg, frozen_noise=True)
real_nfits = pe.gen_nfits_from_event(ev)
print(ev)
# Out:
# Event(E=1538461538461538.5, Xmax=500.0, Nmax=2000000.0, zenith=0.6981317007977318, azimuth=5.497787143782138, corex=450.0, corey=-660.0, corez=-25.7, X0=0, Lambda=70)

# %% [markdown]
# We now have fitted NICHE waveforms, so we can estimate the core position with a tyro fit, and perform a plane fit to estimate the shower direction. We then compile this info into inital guesses to supply to the minimizer.

# %%
ty = tyro(real_nfits)
pf = NichePlane(real_nfits)
plot_event(ty)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
guess = make_guess(ty, pf)
[print(p) for p in guess];
# Out:
# FitParam(name='xmax', value=300.0, limits=(300.0, 600.0), error=50.0)
# FitParam(name='nmax', value=100000.0, limits=(100000.0, 10000000.0), error=100000.0)
# FitParam(name='zenith', value=0.7461656303442169, limits=(0.6461656303442169, 0.8461656303442169), error=0.017453292519943295)
# FitParam(name='azimuth', value=5.444251890619862, limits=(5.344251890619862, 5.5442518906198615), error=0.017453292519943295)
# FitParam(name='corex', value=448.508675996192, limits=(379.5, 489.2), error=5.0)
# FitParam(name='corey', value=-678.2743327381951, limits=(-711.4, -615.1), error=5.0)
# FitParam(name='corez', value=-25.7, limits=(-26.71418695772166, -24.71418695772166), error=1.0)
# FitParam(name='x0', value=0.0, limits=(-100, 100), error=1)
# FitParam(name='lambda', value=70.0, limits=(0, 100), error=1)

# %% [markdown]
# Fitting for the log of xmax and nmax rather than the values themselves results in a better fit, so we use the LogXNParams mapper to go between the fitted parameters and the real ones.

# %%
guess = LogXNParams.adjust_guess(guess)

# %% [markdown]
# Now we can begin the fit procedure, starting by fitting the peaktimes for the shower angles.

# %%
pt = PeakTimes(real_nfits, LogXNParams, cfg)
pt.target_parameters = ['zenith','azimuth']
m = init_minuit(pt, guess)
m.tol = .1
m.simplex()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                               Simplex                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 65.01 (χ²/ndof = 7.2)      │              Nfcn = 39               │
# │ EDM = 2.1 (Goal: 0.1)            │           time = 14.2 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬─────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name    │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼─────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ xmax    │    10     │    50     │            │            │ 5.70378 │ 6.39693 │  yes  │
# │ 1 │ nmax    │     0     │   0.1e6   │            │            │ 11.5129 │ 16.1181 │  yes  │
# │ 2 │ zenith  │ 700.26e-3 │  0.27e-3  │            │            │0.646166 │0.846166 │       │
# │ 3 │ azimuth │  5.5024   │  0.0005   │            │            │ 5.34425 │ 5.54425 │       │
# │ 4 │ corex   │    449    │     5     │            │            │  379.5  │  489.2  │  yes  │
# │ 5 │ corey   │   -678    │     5     │            │            │ -711.4  │ -615.1  │  yes  │
# │ 6 │ corez   │   -25.7   │    1.0    │            │            │-26.7142 │-24.7142 │  yes  │
# │ 7 │ x0      │     0     │     1     │            │            │  -100   │   100   │  yes  │
# │ 8 │ lambda  │    70     │     1     │            │            │    0    │   100   │  yes  │
# └───┴─────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %% [markdown]
# Now with a good estimate for the angles, we can pit the pulse widths to estimate xmax.

# %%
tpguess = update_guess(m)
pw = PulseWidth(real_nfits, LogXNParams, cfg)
pw.target_parameters = ['xmax']
m = init_minuit(pw, tpguess)
m.simplex(ncall=40)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                               Simplex                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 40.07 (χ²/ndof = 4.0)      │              Nfcn = 13               │
# │ EDM = 0.0257 (Goal: 0.1)         │            time = 4.3 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬─────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name    │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼─────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ xmax    │   6.17    │   0.10    │            │            │ 5.70378 │ 6.39693 │       │
# │ 1 │ nmax    │     0     │   0.1e6   │            │            │ 11.5129 │ 16.1181 │  yes  │
# │ 2 │ zenith  │ 700.26e-3 │  0.27e-3  │            │            │0.646166 │0.846166 │  yes  │
# │ 3 │ azimuth │  5.5024   │  0.0005   │            │            │ 5.34425 │ 5.54425 │  yes  │
# │ 4 │ corex   │    449    │     5     │            │            │  379.5  │  489.2  │  yes  │
# │ 5 │ corey   │   -678    │     5     │            │            │ -711.4  │ -615.1  │  yes  │
# │ 6 │ corez   │   -25.7   │    1.0    │            │            │-26.7142 │-24.7142 │  yes  │
# │ 7 │ x0      │     0     │     1     │            │            │  -100   │   100   │  yes  │
# │ 8 │ lambda  │    70     │     1     │            │            │    0    │   100   │  yes  │
# └───┴─────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %% [markdown]
# Now, with a good estimate for log(xmax), we can fit the integrated pulse areas for nmax.

# %%
xmaxguess = update_guess(m)
pa = PulseArea(real_nfits, LogXNParams, cfg)
pa.target_parameters = ['nmax']
m = init_minuit(pa, xmaxguess)
m.simplex(ncall=20)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                               Simplex                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 271 (χ²/ndof = 27.1)       │              Nfcn = 21               │
# │ EDM = 0.216 (Goal: 0.1)          │           time = 12.2 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           ABOVE call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬─────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name    │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼─────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ xmax    │   6.17    │   0.10    │            │            │ 5.70378 │ 6.39693 │  yes  │
# │ 1 │ nmax    │  14.470   │   0.029   │            │            │ 11.5129 │ 16.1181 │       │
# │ 2 │ zenith  │ 700.26e-3 │  0.27e-3  │            │            │0.646166 │0.846166 │  yes  │
# │ 3 │ azimuth │  5.5024   │  0.0005   │            │            │ 5.34425 │ 5.54425 │  yes  │
# │ 4 │ corex   │    449    │     5     │            │            │  379.5  │  489.2  │  yes  │
# │ 5 │ corey   │   -678    │     5     │            │            │ -711.4  │ -615.1  │  yes  │
# │ 6 │ corez   │   -25.7   │    1.0    │            │            │-26.7142 │-24.7142 │  yes  │
# │ 7 │ x0      │     0     │     1     │            │            │  -100   │   100   │  yes  │
# │ 8 │ lambda  │    70     │     1     │            │            │    0    │   100   │  yes  │
# └───┴─────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %% [markdown]
# Now, with these values in the ballpark, we can simultaneously minimize both the shower profile and core position by fitting the normalized pulse areas.

# %%
nmaxguess = update_guess(m)
pa = NormalizedPulseArea(real_nfits, LogXNParams, cfg)
pa.target_parameters = ['xmax','nmax','corex','corey']
m = init_minuit(pa, nmaxguess)
m.simplex()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                               Simplex                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 13.26 (χ²/ndof = 1.9)      │              Nfcn = 73               │
# │ EDM = 0.0772 (Goal: 0.1)         │           time = 31.2 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬─────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name    │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼─────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ xmax    │   6.225   │   0.005   │            │            │ 5.70378 │ 6.39693 │       │
# │ 1 │ nmax    │  14.466   │   0.007   │            │            │ 11.5129 │ 16.1181 │       │
# │ 2 │ zenith  │ 700.26e-3 │  0.27e-3  │            │            │0.646166 │0.846166 │  yes  │
# │ 3 │ azimuth │  5.5024   │  0.0005   │            │            │ 5.34425 │ 5.54425 │  yes  │
# │ 4 │ corex   │   452.1   │    0.9    │            │            │  379.5  │  489.2  │       │
# │ 5 │ corey   │  -660.2   │    1.0    │            │            │ -711.4  │ -615.1  │       │
# │ 6 │ corez   │   -25.7   │    1.0    │            │            │-26.7142 │-24.7142 │  yes  │
# │ 7 │ x0      │     0     │     1     │            │            │  -100   │   100   │  yes  │
# │ 8 │ lambda  │    70     │     1     │            │            │    0    │   100   │  yes  │
# └───┴─────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
coreguess = update_guess(m)
at = AllTunka(real_nfits, LogXNParams, cfg)
at.target_parameters = ['xmax','nmax','zenith','azimuth','corex','corey']
m = init_minuit(at, coreguess)
m.simplex(ncall = 500)
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                               Simplex                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 123.6 (χ²/ndof = 4.6)      │              Nfcn = 16               │
# │ EDM = 29.1 (Goal: 0.1)           │            time = 7.9 sec            │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │         INVALID Minimum          │   ABOVE EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Hesse not run           │            NO covariance             │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬─────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name    │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼─────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ xmax    │  6.2248   │  0.0005   │            │            │ 5.70378 │ 6.39693 │       │
# │ 1 │ nmax    │  14.4662  │  0.0007   │            │            │ 11.5129 │ 16.1181 │       │
# │ 2 │ zenith  │ 700.26e-3 │  0.06e-3  │            │            │0.646166 │0.846166 │       │
# │ 3 │ azimuth │  5.50241  │  0.00009  │            │            │ 5.34425 │ 5.54425 │       │
# │ 4 │ corex   │  453.02   │   0.17    │            │            │  379.5  │  489.2  │       │
# │ 5 │ corey   │  -660.21  │   0.19    │            │            │ -711.4  │ -615.1  │       │
# │ 6 │ corez   │   -25.7   │    1.0    │            │            │-26.7142 │-24.7142 │  yes  │
# │ 7 │ x0      │     0     │     1     │            │            │  -100   │   100   │  yes  │
# │ 8 │ lambda  │    70     │     1     │            │            │    0    │   100   │  yes  │
# └───┴─────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘

# %%
# curr_xmax = m.params['xmax'].value
# curr_nmax = m.params['nmax'].value
# curr_z = m.params['zenith'].value
# dz = np.deg2rad(1)
# curr_a = m.params['azimuth'].value
# curr_corex = m.params['corex'].value
# dcore = 2.
# curr_corey = m.params['corey'].value
# m.limits['xmax'] = (curr_xmax + np.log(.99), curr_xmax + np.log(1.01))
# m.limits['nmax'] = (curr_nmax + np.log(.99), curr_nmax + np.log(1.01))
# m.limits['zenith'] = (curr_z - dz, curr_z + dz)
# m.limits['azimuth'] = (curr_a - dz, curr_a + dz)
# m.limits['corex'] = (curr_corex - dcore, curr_corex + dcore)
# m.limits['corey'] = (curr_corey - dcore, curr_corey + dcore)
m.migrad()
# Out:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 107.5 (χ²/ndof = 4.0)      │              Nfcn = 823              │
# │ EDM = 1.54e-06 (Goal: 0.0002)    │           time = 367.9 sec           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │     Covariance FORCED pos. def.      │
# └──────────────────────────────────┴──────────────────────────────────────┘
# ┌───┬─────────┬───────────┬───────────┬────────────┬────────────┬─────────┬─────────┬───────┐
# │   │ Name    │   Value   │ Hesse Err │ Minos Err- │ Minos Err+ │ Limit-  │ Limit+  │ Fixed │
# ├───┼─────────┼───────────┼───────────┼────────────┼────────────┼─────────┼─────────┼───────┤
# │ 0 │ xmax    │  6.22331  │  0.00015  │            │            │ 5.70378 │ 6.39693 │       │
# │ 1 │ nmax    │  14.465   │   0.005   │            │            │ 11.5129 │ 16.1181 │       │
# │ 2 │ zenith  │698.6627e-3│ 0.0016e-3 │            │            │0.646166 │0.846166 │       │
# │ 3 │ azimuth │ 5.5024062 │ 0.0000019 │            │            │ 5.34425 │ 5.54425 │       │
# │ 4 │ corex   │ 453.0159  │  0.0010   │            │            │  379.5  │  489.2  │       │
# │ 5 │ corey   │ -660.2073 │  0.0027   │            │            │ -711.4  │ -615.1  │       │
# │ 6 │ corez   │   -25.7   │    1.0    │            │            │-26.7142 │-24.7142 │  yes  │
# │ 7 │ x0      │     0     │     1     │            │            │  -100   │   100   │  yes  │
# │ 8 │ lambda  │    70     │     1     │            │            │    0    │   100   │  yes  │
# └───┴─────────┴───────────┴───────────┴────────────┴────────────┴─────────┴─────────┴───────┘
# ┌─────────┬───────────────────────────────────────────────────────────────────────────────────────────┐
# │         │      xmax      nmax    zenith   azimuth     corex     corey     corez        x0    lambda │
# ├─────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │    xmax │  2.16e-08 -0.009e-6   0.1e-12     0e-12         0         0         0         0         0 │
# │    nmax │ -0.009e-6  3.02e-05  25.3e-12    39e-12         0      0e-6         0         0         0 │
# │  zenith │   0.1e-12  25.3e-12  2.64e-12   0.9e-12 742.7e-12 2.0318e-9         0         0         0 │
# │ azimuth │     0e-12    39e-12   0.9e-12  3.67e-12  1.154e-9  3.162e-9     0e-12     0e-12     0e-12 │
# │   corex │         0         0 742.7e-12  1.154e-9  9.94e-07    2.7e-6      0e-6      0e-6      0e-6 │
# │   corey │         0      0e-6 2.0318e-9  3.162e-9    2.7e-6  7.45e-06      0e-6      0e-6      0e-6 │
# │   corez │         0         0         0     0e-12      0e-6      0e-6         0         0         0 │
# │      x0 │         0         0         0     0e-12      0e-6      0e-6         0         0         0 │
# │  lambda │         0         0         0     0e-12      0e-6      0e-6         0         0         0 │
# └─────────┴───────────────────────────────────────────────────────────────────────────────────────────┘

# %%
fitpars = [p.value for p in m.params]
fit_ev = LogXNParams.get_event(fitpars)
print(fit_ev)
# Out:
# Event(E=1472601893766264.0, Xmax=504.3679830755029, Nmax=1914382.4618961434, zenith=0.6986626948362972, azimuth=5.502406215864405, corex=453.0159224945098, corey=-660.2073209146455, corez=-25.7, X0=0.0, Lambda=70.0)

# %%
fit_nfits = pe.gen_nfits_from_event(fit_ev)
plot_event(tyro(fit_nfits))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
m.fixed['corex'] = True
m.fixed['corey'] = True
m.fixed['nmax'] = True
m.minos()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 4
#       2 m.fixed['corey'] = True
#       3 m.fixed['nmax'] = True
# ----> 4 m.minos()
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/iminuit/minuit.py:1477, in Minuit.minos(self, cl, ncall, *parameters)
#    1474 fm = self._fmin._src
#    1476 if not self.valid:
# -> 1477     raise RuntimeError(f"Function minimum is not valid: {repr(self._fmin)}")
#    1479 if len(parameters) == 0:
#    1480     ipars = [ipar for ipar in range(self.npar) if not self.fixed[ipar]]
#
# RuntimeError: Function minimum is not valid: <FMin algorithm='External' edm=3.5973620799509014 edm_goal=0.0002 errordef=1.0 fval=107.48656653975867 has_accurate_covar=False has_covariance=True has_made_posdef_covar=True has_parameters_at_limit=False has_posdef_covar=False has_reached_call_limit=False has_valid_parameters=False hesse_failed=False is_above_max_edm=True is_valid=False nfcn=882 ngrad=0 reduced_chi2=3.582885551325289 time=18.04875867103692>

# %%
at = AllTunka(real_nfits, BasicParams, cfg)
at.chi2(pars)/44
